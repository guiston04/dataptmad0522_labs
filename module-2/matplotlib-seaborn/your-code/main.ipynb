# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# imports
import numpy as np
import pandas as pd

# matplotlib
import matplotlib.pyplot as plt   # conda install matplotlib

# seaborn
import seaborn as sns   # conda install seaborn

#sqlalchemy
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import inspect

#pandas
import pandas as pd

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

plt.plot(x, y, z, linewidth=4, linestyle='dashed')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig, axs = plt.subplots(ncols=1, nrows=2)
axs[0].plot(x, y)
axs[0].set_xlim(0, 100)
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].grid(False)
axs[1].plot(x, z, color = 'orange', linestyle = 'dashed')
axs[1].set_xlim(0, 100)
axs[1].set_xlabel('x')
axs[1].set_ylabel('z')
axs[1].grid(False)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, axs = plt.subplots(ncols=1, nrows=2, figsize = [15,5])
axs[0].plot(x, y)
axs[0].set_xlim(0, 100)
axs[0].set_xlabel('x')
axs[0].set_ylabel('y', fontsize = '15')
axs[0].grid(False)
axs[1].plot(x, z, color = 'orange', linestyle = 'dashed')
axs[1].set_xlim(0, 100)
axs[1].set_xlabel('x', fontsize = '15')
axs[1].set_ylabel('z', fontsize = '15')
axs[1].grid(False)

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here

x = np.arange(0,100)
y = x**2
z = np.exp(x)

fig, axs = plt.subplots(ncols=1, nrows=2)
axs[0].plot(x, y)
axs[0].set_xlim(0, 100)
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].grid(False)
axs[1].plot(x, z, color = 'orange', linestyle = 'dashed')
axs[1].set_xlim(0, 100)
axs[1].set_xlabel('x')
axs[1].set_ylabel('z')
axs[1].grid(False)
axs[1].set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
x = np.arange(0,100)
y = x**2
z = np.exp(x)

fig, axs = plt.subplots(ncols=1, nrows=2)
axs[0].plot(x, y, label="x**2")
axs[0].set_xlim(0, 100)
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].grid(False)
axs[0].legend(loc='upper left')
axs[1].plot(x, z, color = 'orange', linestyle = 'dashed', label="e**x")
axs[1].set_xlim(0, 100)
axs[1].set_xlabel('x')
axs[1].set_ylabel('z')
axs[1].grid(False)
axs[1].set_yscale('log')
axs[1].legend(loc='upper left')

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here

df_fitbit = pd.read_csv('/Users/guillaumedieude/desktop/ironhack/curso/Los_Labs/dataptmad0522_labs/module-2/matplotlib-seaborn/data/fitbit2.csv')

# %%
fitbit = pd.DataFrame(df_fitbit)
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fitbit_month = fitbit[['Steps','Months_encoded']].copy()
fitbit_month = fitbit_month.groupby(by = ['Months_encoded'], as_index = False).mean()
fitbit_month.head()
# Out:
#    Months_encoded         Steps
# 0               1   9892.064516
# 1               2   8922.866667
# 2               3  10312.935484
# 3               4  13079.033333
# 4               5  10620.096774

# %%
fitbit_work_weekend = fitbit[['Steps','Work_or_Weekend']].copy()
fitbit_work_weekend = fitbit_work_weekend.groupby(by = ['Work_or_Weekend'], as_index = False).mean()
fitbit_work_weekend.head()
# Out:
#    Work_or_Weekend         Steps
# 0                0  10064.238095
# 1                1  10144.572519

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

x1 = fitbit_month['Months_encoded']
y1 = fitbit_month['Steps']

x2 = fitbit_work_weekend['Work_or_Weekend']
y2 = fitbit_work_weekend['Steps']

labels = ['Workday', 'Weekend']

fig, axs = plt.subplots(ncols=1, nrows=2, figsize = [12,4])
plt.sca(axs[0])
plt.plot(x1, y1)
plt.xticks(x1)
axs[0].set_xlim(0, 12)
axs[0].set_xlabel('Month')
axs[0].set_ylabel('avg.steps')
axs[0].grid(False)

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

plt.sca(axs[1])
plt.plot(x2, y2)
plt.xticks(x2, labels)
axs[1].set_xlabel('workday or weekend')
axs[1].set_ylabel('avg.steps')
axs[1].grid(False)
plt.savefig('/Users/guillaumedieude/desktop/ironhack/curso/Los_Labs/dataptmad0522_labs/module-2/matplotlib-seaborn/figures/figures.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

lista = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']
fig, axs = plt.subplots(ncols=1, nrows=3, figsize = [12,4])

for i in range(len(lista)):
    graph = fitbit[['Steps',lista[i]]].copy()
    graph = graph.groupby(by = [list[i]], as_index = False).mean()
    
    x = graph[lista[i]]
    y = graph['Steps']
             

    plt.sca(axs[i])
    plt.plot(x, y)
    plt.xticks(x)
    axs[i].set_xlabel(lista[i])
    axs[i].set_ylabel('avg.steps')
    axs[i].grid(False)

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('/Users/guillaumedieude/desktop/ironhack/curso/Los_Labs/dataptmad0522_labs/module-2/matplotlib-seaborn/data/titanic.csv')

# %%
# your code here

titanic = pd.DataFrame(titanic)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

titanic.select_dtypes(exclude = 'object')
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here

titanic.select_dtypes(include = 'object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

#import matplotlib.style
import matplotlib.style
import matplotlib as mpl


mpl.style.use('classic')

fig = plt.figure(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

x = titanic['Age']
plt.hist(x)
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

fig, axs = plt.subplots(ncols=1, nrows=3, figsize = [12,6])
bins  = [10, 20, 50]

for i in range(len(bins)):

    x = titanic['Age']
    axs[i].hist(x, bins = bins[i])

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The bin size seems to affect the level of precision of the graph. This can be observed in the 20 to 30s range
where you can see a gap forming in the middle when the bin size is smaller.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

sns.histplot(x)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic_gender = titanic[['Gender', 'PassengerId']].copy()
titanic_gender = titanic_gender.groupby(by = ['Gender'], as_index = False).count()
titanic_gender.head()
# Out:
#    Gender  PassengerId
# 0  female          466
# 1    male          843

# %%
# Method 1 - matplotlib
# your code here

labels = ['Female' , 'Male']
x = titanic_gender['PassengerId']

fig1, ax1 = plt.subplots()
ax1.pie(x, labels=labels, startangle=90, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# Method 2 - seaborn
# your code here

ax = sns.barplot(x=titanic_gender['Gender'], y=titanic_gender['PassengerId'])

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
titanic_Pclass = titanic[['Pclass', 'PassengerId']].copy()
titanic_Pclass = titanic_Pclass.groupby(by = ['Pclass'], as_index = False).count()
titanic_Pclass.head()
# Out:
#    Pclass  PassengerId
# 0       1          323
# 1       2          277
# 2       3          709

# %%
# your code here

labels = ['Class1' , 'Class2', 'Class3']
x = titanic_Pclass['PassengerId']

fig1, ax1 = plt.subplots()
ax1.pie(x, labels=labels, startangle=90, autopct='%1.1f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
x = titanic['Age']

print(titanic['Age'].unique())
plt.boxplot(x)
# Out:
# [22.         38.         26.         35.         23.92650162 54.
#   2.         27.         14.          4.         58.         20.
#  39.         55.         32.17286773 31.         27.74983609 34.
#  15.         28.          8.         19.         22.58128264 27.8241802
#  40.         49.68049833 32.69341682 66.         42.         23.75223651
#  21.         18.          3.         29.51319025 32.3396619  23.10544623
#   7.         49.         29.         65.         43.87959266 28.5
#   5.         11.         45.         40.18155172  8.26579594 17.
#  32.         16.         25.          0.83       30.         23.09506372
#  33.         23.         24.         46.         59.         71.
#  37.         26.47603604 32.97273753 47.         14.5        70.5
#  32.5        12.         25.31543497 23.92883813  9.         36.5
#  51.         55.5        40.5        22.96031486 24.42796139 13.55109286
#  44.          1.         25.90327024 47.93086987 61.         56.
# ...

# %%
"""
The boxplot is a great plot to get the summary statistics. It gives you information about the median,
the first quartile, the third quartile, the min and the max
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
About half of the passengers where between 20 and 40 years old. The youngest passenger 
was a 1 year old and the older was a 59 year old. 50 % of the passengers were younger than 30 years old,
75% were younger than 40 years and about 25% younger than 25 years old.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# plotting two histograms on the same axis
plt.hist(titanic['Fare'], color='green')
plt.hist(titanic['Age'], color='blue')
  
plt.title("histogram with multiple \
variables (overlapping histogram)")
  
plt.legend(['Fare', 
            'Age'])
  
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.histplot(titanic['Fare'], color="skyblue", label="Fare", kde=True)
sns.histplot(titanic['Age'], color="green", label="Age", kde=True)

plt.legend() 
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# Compute the correlation matrix
corr = titanic.corr()
print(corr)

# Generate a mask for the upper triangle
#mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
It seems that the richest passengers had an higher surviving rate.
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

x = titanic['Age']
y = titanic['Pclass']


fig=plt.figure(figsize = [12,6])
ax=fig.add_axes([0,0,1,1])
ax.scatter(x, y, color='r')
ax.set_xlabel('Age')
ax.set_ylabel('Pclass')
ax.set_title('scatter plot')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here

sns.scatterplot(data=titanic, x="Age", y="Pclass")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pclass'>
